# %% [markdown]
# ## Exploratory Data Analysis for NBA 2019 league

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read dataset
df = pd.read_csv('https://raw.githubusercontent.com/olegoid/predicting_models_NBA_games/codespace-0eb1/data/2019_advanced_plus_totals.csv')
df.shape
# Out:
# (529, 49)

# %%
df.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP          int64
# FG          int64
# FGA         int64
# FG%       float64
# 3P          int64
# 3PA         int64
# 3P%       float64
# 2P          int64
# 2PA         int64
# 2P%       float64
# eFG%      float64
# FT          int64
# FTA         int64
# FT%       float64
# ORB         int64
# DRB         int64
# TRB         int64
# AST         int64
# STL         int64
# BLK         int64
# TOV         int64
# PF          int64
# PTS         int64
# 3PAr      float64
# AST%      float64
# BLK%      float64
# BPM       float64
# DBPM      float64
# DRB%      float64
# DWS       float64
# FTr       float64
# OBPM      float64
# ORB%      float64
# OWS       float64
# PER       float64
# STL%      float64
# TOV%      float64
# TRB%      float64
# TS%       float64
# USG%      float64
# VORP      float64
# WS        float64
# WS/48     float64
# dtype: object

# %%
df['Pos'] = df['Pos'].astype('category')
df['Tm'] = df['Tm'].astype('category')
df.dtypes
# Out:
# Player      object
# Pos       category
# Age          int64
# Tm        category
# G            int64
# GS           int64
# MP           int64
# FG           int64
# FGA          int64
# FG%        float64
# 3P           int64
# 3PA          int64
# 3P%        float64
# 2P           int64
# 2PA          int64
# 2P%        float64
# eFG%       float64
# FT           int64
# FTA          int64
# FT%        float64
# ORB          int64
# DRB          int64
# TRB          int64
# AST          int64
# STL          int64
# BLK          int64
# TOV          int64
# PF           int64
# PTS          int64
# 3PAr       float64
# AST%       float64
# BLK%       float64
# BPM        float64
# DBPM       float64
# DRB%       float64
# DWS        float64
# FTr        float64
# OBPM       float64
# ORB%       float64
# OWS        float64
# PER        float64
# STL%       float64
# TOV%       float64
# TRB%       float64
# TS%        float64
# USG%       float64
# VORP       float64
# ...

# %%
df['Pos'].value_counts().plot(kind='bar', title='Pos')
# Out:
# <AxesSubplot: title={'center': 'Pos'}>

# %%
sns.set_style("whitegrid")
sns.boxplot(y='Age', data=df)
df.hist(column='Age')
# Out:
# array([[<AxesSubplot: title={'center': 'Age'}>]], dtype=object)

# %%
sns.boxplot(y='G', data=df)
df.hist(column='G')
# Out:
# array([[<AxesSubplot: title={'center': 'G'}>]], dtype=object)

# %%
sns.boxplot(y='GS', data=df)
df.hist(column='GS')
# Out:
# array([[<AxesSubplot: title={'center': 'GS'}>]], dtype=object)

# %%
sns.boxplot(y='MP', data=df)
df.hist(column='MP')
# Out:
# array([[<AxesSubplot: title={'center': 'MP'}>]], dtype=object)

# %%
sns.boxplot(y='FG', data=df)
df.hist(column='FG')
# Out:
# array([[<AxesSubplot: title={'center': 'FG'}>]], dtype=object)

# %%
sns.boxplot(y='FGA', data=df)
df.hist(column='FGA')
# Out:
# array([[<AxesSubplot: title={'center': 'FGA'}>]], dtype=object)

# %%
sns.boxplot(y='3P', data=df)
df.hist(column='3P')
# Out:
# array([[<AxesSubplot: title={'center': '3P'}>]], dtype=object)

# %%
sns.boxplot(y='3PA', data=df)
df.hist(column='3PA')
# Out:
# array([[<AxesSubplot: title={'center': '3PA'}>]], dtype=object)

# %%
sns.boxplot(y='2P', data=df)
df.hist(column='2P')
# Out:
# array([[<AxesSubplot: title={'center': '2P'}>]], dtype=object)

# %%
sns.boxplot(y='2PA', data=df)
df.hist(column='2PA')
# Out:
# array([[<AxesSubplot: title={'center': '2PA'}>]], dtype=object)

# %%
sns.boxplot(y='eFG%', data=df)
df.hist(column='eFG%')
# Out:
# array([[<AxesSubplot: title={'center': 'eFG%'}>]], dtype=object)

# %%
sns.boxplot(y='FT', data=df)
df.hist(column='FT')
# Out:
# array([[<AxesSubplot: title={'center': 'FT'}>]], dtype=object)

# %%
sns.boxplot(y='FTA', data=df)
df.hist(column='FTA')
# Out:
# array([[<AxesSubplot: title={'center': 'FTA'}>]], dtype=object)

# %%
sns.boxplot(y='ORB', data=df)
df.hist(column='ORB')
# Out:
# array([[<AxesSubplot: title={'center': 'ORB'}>]], dtype=object)

# %%
sns.boxplot(y='DRB', data=df)
df.hist(column='DRB')
# Out:
# array([[<AxesSubplot: title={'center': 'DRB'}>]], dtype=object)

# %%
sns.boxplot(y='TRB', data=df)
df.hist(column='TRB')
# Out:
# array([[<AxesSubplot: title={'center': 'TRB'}>]], dtype=object)

# %%
sns.boxplot(y='AST', data=df)
df.hist(column='AST')
# Out:
# array([[<AxesSubplot: title={'center': 'AST'}>]], dtype=object)

# %%
sns.boxplot(y='STL', data=df)
df.hist(column='STL')
# Out:
# array([[<AxesSubplot: title={'center': 'STL'}>]], dtype=object)

# %%
sns.boxplot(y='BLK', data=df)
df.hist(column='BLK')
# Out:
# array([[<AxesSubplot: title={'center': 'BLK'}>]], dtype=object)

# %%
sns.boxplot(y='TOV', data=df)
df.hist(column='TOV')
# Out:
# array([[<AxesSubplot: title={'center': 'TOV'}>]], dtype=object)

# %%
sns.boxplot(y='PF', data=df)
df.hist(column='PF')
# Out:
# array([[<AxesSubplot: title={'center': 'PF'}>]], dtype=object)

# %%
sns.boxplot(y='PTS', data=df)
df.hist(column='PTS')
# Out:
# array([[<AxesSubplot: title={'center': 'PTS'}>]], dtype=object)
