# %% [markdown]
# ## Exploratory Data Analysis for NBA 2019 league

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read dataset
df = pd.read_csv('https://raw.githubusercontent.com/olegoid/predicting_models_NBA_games/codespace-0eb1/data/2019_advanced.csv')
df.shape
# Out:
# (529, 28)

# %%
df.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# MP          int64
# PER       float64
# TS%       float64
# 3PAr      float64
# FTr       float64
# ORB%      float64
# DRB%      float64
# TRB%      float64
# AST%      float64
# STL%      float64
# BLK%      float64
# TOV%      float64
# USG%      float64
#           float64
# OWS       float64
# DWS       float64
# WS        float64
# WS/48     float64
#  .1       float64
# OBPM      float64
# DBPM      float64
# BPM       float64
# VORP      float64
# dtype: object

# %%
df['Pos'] = df['Pos'].astype('category')
df['Tm'] = df['Tm'].astype('category')

df = df.drop(df.columns[[23, 18]],axis = 1)
df.dtypes
# Out:
# Player      object
# Pos       category
# Age          int64
# Tm        category
# G            int64
# MP           int64
# PER        float64
# TS%        float64
# 3PAr       float64
# FTr        float64
# ORB%       float64
# DRB%       float64
# TRB%       float64
# AST%       float64
# STL%       float64
# BLK%       float64
# TOV%       float64
# USG%       float64
# OWS        float64
# DWS        float64
# WS         float64
# WS/48      float64
# OBPM       float64
# DBPM       float64
# BPM        float64
# VORP       float64
# dtype: object

# %%
df['Pos'].value_counts().plot(kind='bar', title='Pos')
# Out:
# <AxesSubplot: title={'center': 'Pos'}>

# %%
sns.set_style("whitegrid")
sns.boxplot(y='Age', data=df)
df.hist(column='Age')
# Out:
# array([[<AxesSubplot: title={'center': 'Age'}>]], dtype=object)

# %%
sns.boxplot(y='G', data=df)
df.hist(column='G')
# Out:
# array([[<AxesSubplot: title={'center': 'G'}>]], dtype=object)

# %%
sns.boxplot(y='MP', data=df)
df.hist(column='MP')
# Out:
# array([[<AxesSubplot: title={'center': 'MP'}>]], dtype=object)

# %%
sns.boxplot(y='PER', data=df)
df.hist(column='PER')
# Out:
# array([[<AxesSubplot: title={'center': 'PER'}>]], dtype=object)

# %%
sns.boxplot(y='TS%', data=df)
df.hist(column='TS%')
# Out:
# array([[<AxesSubplot: title={'center': 'TS%'}>]], dtype=object)

# %%
sns.boxplot(y='3PAr', data=df)
df.hist(column='3PAr')
# Out:
# array([[<AxesSubplot: title={'center': '3PAr'}>]], dtype=object)

# %%
sns.boxplot(y='FTr', data=df)
df.hist(column='FTr')
# Out:
# array([[<AxesSubplot: title={'center': 'FTr'}>]], dtype=object)

# %%
sns.boxplot(y='ORB%', data=df)
df.hist(column='ORB%')
# Out:
# array([[<AxesSubplot: title={'center': 'ORB%'}>]], dtype=object)

# %%
sns.boxplot(y='DRB%', data=df)
df.hist(column='DRB%')
# Out:
# array([[<AxesSubplot: title={'center': 'DRB%'}>]], dtype=object)

# %%
sns.boxplot(y='TRB%', data=df)
df.hist(column='TRB%')
# Out:
# array([[<AxesSubplot: title={'center': 'TRB%'}>]], dtype=object)

# %%
sns.boxplot(y='AST%', data=df)
df.hist(column='AST%')
# Out:
# array([[<AxesSubplot: title={'center': 'AST%'}>]], dtype=object)

# %%
sns.boxplot(y='STL%', data=df)
df.hist(column='STL%')
# Out:
# array([[<AxesSubplot: title={'center': 'STL%'}>]], dtype=object)

# %%
sns.boxplot(y='BLK%', data=df)
df.hist(column='BLK%')
# Out:
# array([[<AxesSubplot: title={'center': 'BLK%'}>]], dtype=object)

# %%
sns.boxplot(y='TOV%', data=df)
df.hist(column='TOV%')
# Out:
# array([[<AxesSubplot: title={'center': 'TOV%'}>]], dtype=object)

# %%
sns.boxplot(y='USG%', data=df)
df.hist(column='USG%')
# Out:
# array([[<AxesSubplot: title={'center': 'USG%'}>]], dtype=object)

# %%
sns.boxplot(y='OWS', data=df)
df.hist(column='OWS')
# Out:
# array([[<AxesSubplot: title={'center': 'OWS'}>]], dtype=object)

# %%
sns.boxplot(y='DWS', data=df)
df.hist(column='DWS')
# Out:
# array([[<AxesSubplot: title={'center': 'DWS'}>]], dtype=object)

# %%
sns.boxplot(y='WS', data=df)
df.hist(column='WS')
# Out:
# array([[<AxesSubplot: title={'center': 'WS'}>]], dtype=object)
