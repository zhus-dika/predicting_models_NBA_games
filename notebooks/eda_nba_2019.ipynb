# %% [markdown]
# ## Exploratory Data Analysis for NBA 2019 league

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read dataset
df = pd.read_csv('https://raw.githubusercontent.com/olegoid/predicting_models_NBA_games/codespace-0eb1/data/2019_advanced.csv')
df.shape
# Out:
# (529, 28)

# %%
df.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# MP          int64
# PER       float64
# TS%       float64
# 3PAr      float64
# FTr       float64
# ORB%      float64
# DRB%      float64
# TRB%      float64
# AST%      float64
# STL%      float64
# BLK%      float64
# TOV%      float64
# USG%      float64
#           float64
# OWS       float64
# DWS       float64
# WS        float64
# WS/48     float64
#  .1       float64
# OBPM      float64
# DBPM      float64
# BPM       float64
# VORP      float64
# dtype: object

# %%
df['Pos'] = df['Pos'].astype('category')
df['Tm'] = df['Tm'].astype('category')

df = df.drop(df.columns[[23, 18]],axis = 1)
df.dtypes
# Out:
# Player      object
# Pos       category
# Age          int64
# Tm        category
# G            int64
# MP           int64
# PER        float64
# TS%        float64
# 3PAr       float64
# FTr        float64
# ORB%       float64
# DRB%       float64
# TRB%       float64
# AST%       float64
# STL%       float64
# BLK%       float64
# TOV%       float64
# USG%       float64
# OWS        float64
# DWS        float64
# WS         float64
# WS/48      float64
# OBPM       float64
# DBPM       float64
# BPM        float64
# VORP       float64
# dtype: object

# %%
categorical = ['Player', 'Pos', "Tm"]

for (columnName, columnData) in df.iteritems():
    if columnName not in categorical:
        df.hist(column='{}'.format(columnName))
# Out:
# /tmp/ipykernel_8709/2948348545.py:3: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for (columnName, columnData) in df.iteritems():
# /home/codespace/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/tools.py:228: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(**fig_kw)

# %%
df['Pos'].value_counts().plot(kind='bar', title='Pos')
# Out:
# <AxesSubplot: title={'center': 'Pos'}>
